# %%
from multiqc_jupyterlab import MultiQC

# %%
m = MultiQC()
# Out:
#   /// ]8;id=108034;https://multiqc.info\MultiQC]8;;\ 🔍 | JupyterLab extension
# MultiQC initialized in JupyterLab. Usage:
# - load(data_dir, file_list, overwrite) 	- load new data,
# - get_modules() 			- get a list of available modules,
# - get_samples(module) 			- get list of samples for a given module,
# - show(module, samples) 		- see the report for a given module and list of samples.

# %%
m.load('./data')

# %%
m.load('./data2')

# %%
m.load('./data3')

# %%
m.get_modules()
# Out:
# ['Picard',
#  'GATK',
#  'Cutadapt',
#  'QualiMap',
#  'FastQC',
#  'Bismark',
#  'SnpEff',
#  'STAR',
#  'featureCounts',
#  'FastQ Screen']

# %%
m.get_samples('fastqc')
# Out:
# ['P4107_1002_S2_L003_R2_001',
#  'SRR3192657_2_val_2',
#  'P4107_1004_S4_L005_R1_001',
#  'SRR3192398_1_val_1',
#  'SRR3192398_2',
#  'SRR3192401_2_val_2',
#  'SRR3192400_2',
#  'SRR3192401_2',
#  'SRR3192399_2_val_2',
#  'SRR3192658_1_val_1',
#  'MethylC-Seq_mm_fc_1wk_SRR921767_1',
#  'P4107_1001_S1_L002_R2_001',
#  'SRR3192398_2_val_2',
#  'SRR3192396_1_val_1',
#  'P4107_1005_S5_L006_R1_001',
#  'SRR3192397_2',
#  'SRR3192401_1_val_1',
#  'P4107_1001_S1_L002_R1_001',
#  'SRR3192657_1',
#  'P4107_1005_S5_L006_R2_001',
#  'SRR3192396_2',
#  'SRR3192399_1',
#  'SRR3192400_1_val_1',
#  'P4107_1003_S3_L004_R2_001',
#  'SRR3192399_1_val_1',
#  'SRR3192400_2_val_2',
#  'SRR3192396_2_val_2',
#  'P4107_1006_S6_L007_R1_001',
#  'SRR3192658_1',
#  'SRR3192397_2_val_2',
#  'SRR3192401_1',
#  'MethylC-Seq_mm_fc_2wk_SRR921695_1',
#  'P4107_1002_S2_L003_R1_001',
#  'P4107_1003_S3_L004_R1_001',
#  'P4107_1004_S4_L005_R2_001',
#  'SRR3192400_1',
#  'SRR3192657_2',
#  'SRR3192396_1',
# ...

# %%
m.show('fastqc', [ 'SRR3192401_1',
 'MethylC-Seq_mm_fc_2wk_SRR921695_1',
 'P4107_1002_S2_L003_R1_001',])
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#
#
#
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <meta name="description" content="MultiQC: A modular tool to aggregate results from bioinformatics analyses across many samples into a single report">
# <meta name="author" content="MultiQC">
# <title>MultiQC Report</title>
#
# <!-- JSON plot data -->
# <script type="text/plain" id="mqc_compressed_plotdata">...</script>
#
# <script type="application/json" id="mqc_config">{"decimalPoint_format": null, "num_datasets_plot_limit": 50, "sample_names_rename": [], "show_hide_mode": [], "show_hide_patterns": [], "show_hide_regex": [], "thousandsSep_format": null}</script>
#
# <!-- Instead of saving data directly into variables in a normal <script>, data is separated into
#      above non-executed script blocks. This way, potential Content Security Policy restrictions
# ...

# %%
m.get_samples('featurecounts')

# %%
m.show('featurecounts', ['SRR3192396_1', 'SRR3192401_1'])

# %%
m.get_samples('fastqc')

# %%
m.show('fastqc', ['SRR3192397_2', 'MethylC-Seq_mm_fc_1wk_SRR921767_1'])

# %%
m.show('FastQ_Screen', ['P4107_1005_S5_L006_R1_001_screen',
 'P4107_1006_S6_L007_R1_001_screen',
 'P4107_1006_S6_L007_R2_001_screen',])
